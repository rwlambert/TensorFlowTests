# %% [markdown]
# # TensorFlow for linear fitting, ROOT is obviously better for this sort of thing

# %%
from IPython.display import YouTubeVideo
print ("https://github.com/MorvanZhou/tutorials/tree/master/tensorflowTUT")
YouTubeVideo('PFijwks2K6o')
# Out:
# https://github.com/MorvanZhou/tutorials/tree/master/tensorflowTUT

# %%
import tensorflow as tf
import pandas as pd
import sys
import tqdm
if 'seaborn' not in sys.modules:
    # %pylab inline
    import seaborn
sess = tf.InteractiveSession()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Generating some data

# %%
n_data = 500
x_data = np.random.rand(n_data).astype(np.float32)
y_data = x_data*0.1 + 0.3 + np.random.normal(loc=0, scale=0.013, size=n_data)
plt.scatter(x_data, y_data, marker='x')
from scipy import stats
stats.spearmanr(x_data,y_data)
# Out:
# SpearmanrResult(correlation=0.91414503258013036, pvalue=2.0476157434798867e-197)

# %% [markdown]
# # Fit the data with root, to get an idea of the stat variation in this set

# %%
# All preamble to configure plotting ...
import ROOT
import rootnotes
import root_pandas
import array
c = rootnotes.canvas()
ROOT.gStyle.SetOptStat('RMe')
ROOT.gStyle.SetOptFit(1111) # Chi2, CHi2 prob, params and uncertainties
ROOT.gStyle.SetStatY(0.8) # move the box out the way of the fit
ROOT.gStyle.SetStatX(0.4)
ROOT.gStyle.SetStatW(0.2)
ROOT.gStyle.SetStatH(0.2)

# %%
# one line to prepare something ROOT can fit ...
graph = ROOT.TGraph(len(x_data),array.array('f',x_data),array.array('f',y_data))
graph.Draw('A*') #A = axis, * = point shape *
# Least squares with Migrad etc.
graph.Fit("pol1")
c
# Out:
# <ROOT.TCanvas object ("icanvas") at 0x5b638a0>

# %% [markdown]
# # Same thing with TensorFlow

# %%
m = tf.Variable(tf.random_uniform([1],-1.,1.), "var_m")
c = tf.Variable(tf.random_uniform([1],-0.5,0.5), "var_c")

y = m*x_data + c
penalty = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(penalty)

# %%
init = tf.initialize_all_variables()
sess.run(init)

# %%
for step in tqdm.tqdm(range(200)):
    sess.run(train)
    if step%20==0:
        print(sess.run(penalty),sess.run(m),sess.run(c))
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 2877.28it/s]
# (0.025102222, array([-0.30260026], dtype=float32), array([ 0.60952753], dtype=float32))
# (0.0012451828, array([-0.01753284], dtype=float32), array([ 0.36276588], dtype=float32))
# (0.00024030324, array([ 0.06643399], dtype=float32), array([ 0.31800434], dtype=float32))
# (0.00017298742, array([ 0.08816647], dtype=float32), array([ 0.30641904], dtype=float32))
# (0.00016847803, array([ 0.09379131], dtype=float32), array([ 0.30342051], dtype=float32))
# (0.00016817593, array([ 0.09524715], dtype=float32), array([ 0.30264443], dtype=float32))
# (0.00016815573, array([ 0.09562394], dtype=float32), array([ 0.30244356], dtype=float32))
# (0.00016815437, array([ 0.09572148], dtype=float32), array([ 0.30239159], dtype=float32))
# (0.00016815426, array([ 0.09574673], dtype=float32), array([ 0.30237812], dtype=float32))
# (0.00016815423, array([ 0.09575325], dtype=float32), array([ 0.30237463], dtype=float32))

# %%
writer = tf.train.SummaryWriter('/tmp/test', sess.graph)

# %%
y_eval = sess.run(y)
plt.scatter(x_data, y_data, marker='x')
plt.scatter(x_data, y_eval, marker='.', color='red')

# %%
# %load_ext watermark
# %watermark -a ThinkBig -d -t -v -p numpy,pandas -g
# Out:
# ThinkBig 2016-10-13 14:11:51
#
# CPython 2.7.12
# IPython 4.2.0
#
# numpy 1.11.1
# pandas 0.18.1
# Git hash:
